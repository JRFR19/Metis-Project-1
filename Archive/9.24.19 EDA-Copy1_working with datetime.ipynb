# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline 
df = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_190921.txt', parse_dates=[['DATE', 'TIME']])
df['day_of_week'] = df['DATE_TIME'].dt.weekday_name
df.columns
# Out:
# Index(['DATE_TIME', 'C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               ',
#        'day_of_week'],
#       dtype='object')

# %%
# Rename exit
df.rename(columns ={"EXITS                                                               ":"EXITS"}, inplace=True)

# %%
# Get only regular/ working units. The irregulars could be contributing to outliers
df = df[df['DESC'] == 'REGULAR']

# %%
df.describe()
# Out:
#             ENTRIES         EXITS
# count  2.042350e+05  2.042350e+05
# mean   4.215594e+07  3.490572e+07
# std    2.157581e+08  1.996471e+08
# min    0.000000e+00  0.000000e+00
# 25%    2.896500e+05  1.292280e+05
# 50%    2.038905e+06  1.178385e+06
# 75%    6.615760e+06  4.534095e+06
# max    2.129093e+09  2.123772e+09

# %%
# Create dif scores for entries / exits
df['ENTRIES_diff'] = df.ENTRIES.diff()
df['EXITS_diff'] = df.EXITS.diff()

# %%
# Replace outliers: delete under zero, replace > 20,000 with mean
# GROUPED BY STATION-- so means are coming by station

df['ENTRIES_diff'] = df.groupby(['STATION']).ENTRIES_diff.transform(
    lambda x: np.where((x<0)|(x>20000),x.mask((x<0)|(x>20000)).mean(),x))

# %%
df.ENTRIES_diff.describe()
# Out:
# count    204234.000000
# mean        188.768041
# std         360.117240
# min           0.000000
# 25%          10.000000
# 50%          84.000000
# 75%         254.000000
# max       19998.000000
# Name: ENTRIES_diff, dtype: float64

# %%
df['EXITS_diff'] = df.groupby(['STATION']).EXITS_diff.transform(
    lambda x: np.where((x<0)|(x>20000),x.mask((x<0)|(x>20000)).mean(),x))

# %%
df.EXITS_diff.describe()
# Out:
# count    204234.000000
# mean        153.670505
# std         372.759533
# min           0.000000
# 25%           9.000000
# 50%          60.000000
# 75%         182.458537
# max       19987.000000
# Name: EXITS_diff, dtype: float64

# %%
df.columns
# Out:
# Index(['DATE_TIME', 'C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION',
#        'DESC', 'ENTRIES', 'EXITS', 'day_of_week', 'ENTRIES_diff',
#        'EXITS_diff'],
#       dtype='object')

# %%
# Create 'traffic_flow'.
df['TRAFFIC_FLOW'] = df['ENTRIES_diff'] + df['EXITS_diff']

# %%
df.head()
# Out:
#             DATE_TIME   C/A  UNIT       SCP STATION LINENAME DIVISION  \
# 0 2019-09-14 00:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 1 2019-09-14 04:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 2 2019-09-14 08:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 3 2019-09-14 12:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 4 2019-09-14 16:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
#
#       DESC  ENTRIES    EXITS day_of_week  ENTRIES_diff  EXITS_diff  \
# 0  REGULAR  7198818  2438323    Saturday           NaN         NaN
# 1  REGULAR  7198834  2438325    Saturday          16.0         2.0
# 2  REGULAR  7198847  2438354    Saturday          13.0        29.0
# 3  REGULAR  7198929  2438428    Saturday          82.0        74.0
# 4  REGULAR  7199125  2438483    Saturday         196.0        55.0
#
#    TRAFFIC_FLOW
# 0           NaN
# 1          18.0
# 2          42.0
# 3         156.0
# 4         251.0

# %%
df['TRAFFIC_FLOW'].describe()
# Out:
# count    204234.000000
# mean        342.438546
# std         572.652692
# min           0.000000
# 25%          32.000000
# 50%         193.000000
# 75%         485.825784
# max       38027.000000
# Name: TRAFFIC_FLOW, dtype: float64

# %%
# set date_time to index
df.set_index('DATE_TIME', inplace = True)

# %%
df.head()
# Out:
#                       C/A  UNIT       SCP STATION LINENAME DIVISION     DESC  \
# DATE_TIME
# 2019-09-14 00:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT  REGULAR
# 2019-09-14 04:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT  REGULAR
# 2019-09-14 08:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT  REGULAR
# 2019-09-14 12:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT  REGULAR
# 2019-09-14 16:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT  REGULAR
#
#                      ENTRIES    EXITS day_of_week  ENTRIES_diff  EXITS_diff  \
# DATE_TIME
# 2019-09-14 00:00:00  7198818  2438323    Saturday           NaN         NaN
# 2019-09-14 04:00:00  7198834  2438325    Saturday          16.0         2.0
# 2019-09-14 08:00:00  7198847  2438354    Saturday          13.0        29.0
# 2019-09-14 12:00:00  7198929  2438428    Saturday          82.0        74.0
# 2019-09-14 16:00:00  7199125  2438483    Saturday         196.0        55.0
#
#                      TRAFFIC_FLOW
# DATE_TIME
# 2019-09-14 00:00:00           NaN
# 2019-09-14 04:00:00          18.0
# 2019-09-14 08:00:00          42.0
# 2019-09-14 12:00:00         156.0
# 2019-09-14 16:00:00         251.0

# %%
df['ENTRIES'].describe()
# Out:
# count    2.042350e+05
# mean     4.215594e+07
# std      2.157581e+08
# min      0.000000e+00
# 25%      2.896500e+05
# 50%      2.038905e+06
# 75%      6.615760e+06
# max      2.129093e+09
# Name: ENTRIES, dtype: float64

# %%
# Look at station level
gp_station = df.groupby('STATION')

# %%
# summing all entries_diff (which is 4 hour segments of entries), summing (so getting across all dates in data),
# showing highest 5 
gp_station['TRAFFIC_FLOW'].sum().sort_values().tail(5)#(ascending=False)[:5]
# Out:
# STATION
# 14 ST-UNION SQ     1.317749e+06
# 23 ST              1.336954e+06
# 34 ST-HERALD SQ    1.524057e+06
# GRD CNTRL-42 ST    1.788344e+06
# 34 ST-PENN STA     2.016361e+06
# Name: TRAFFIC_FLOW, dtype: float64

# %% [markdown]
# ### Now that we have the top 5 stations, we can focus on which exits/entries within to focus on. We can also do some kind of analysis by day of week, or time of day

# %%
# Making a df with top 5 entries
top_entry_stations = df[df['STATION'].isin(['34 ST-PENN STA','GRD CNTRL-42 ST', '34 ST-HERALD SQ', '23 ST', '14 ST-UNION SQ' ])]

# %%
top_entry_stations.describe()
# Out:
#             ENTRIES  \
# count  1.432100e+04
# mean   4.989727e+07
# std    2.283851e+08
# min    0.000000e+00
# 25%    4.777420e+05
# 50%    3.065873e+06
# 75%    8.670853e+06
# max    1.999726e+09
#
#        EXITS
# count                                       1.432100e+04
# mean                                        5.423042e+07
# std                                         2.585205e+08
# min                                         0.000000e+00
# 25%                                         3.898730e+05
# 50%                                         2.121371e+06
# 75%                                         6.666645e+06
# max                                         2.048716e+09

# %%
# Making a df with top 5 entries with nunique
test_top_entry_stations = df[df['STATION'].isin(['34 ST-PENN STA','GRD CNTRL-42 ST', '34 ST-HERALD SQ', '23 ST', '14 ST-UNION SQ' ])].nunique()

# %%
teeeop_entry_stations.describe()
# Out:
# count       11.000000
# mean      2352.636364
# std       5151.966057
# min          2.000000
# 25%          6.000000
# 50%         17.000000
# 75%        122.500000
# max      12820.000000
# dtype: float64

# %%
top_entry_stations.groupby('day_of_week')['TRAFFIC_FLOW'].mean().plot(kind='area')

# %%
# main df not top stations
# df.groupby('day_of_week').mean()

# %%
top_entry_stations.head()
# Out:
#                       C/A  UNIT       SCP          STATION  LINENAME DIVISION  \
# DATE_TIME
# 2019-09-14 00:00:00  A022  R022  01-00-00  34 ST-HERALD SQ  BDFMNQRW      BMT
# 2019-09-14 04:00:00  A022  R022  01-00-00  34 ST-HERALD SQ  BDFMNQRW      BMT
# 2019-09-14 08:00:00  A022  R022  01-00-00  34 ST-HERALD SQ  BDFMNQRW      BMT
# 2019-09-14 12:00:00  A022  R022  01-00-00  34 ST-HERALD SQ  BDFMNQRW      BMT
# 2019-09-14 16:00:00  A022  R022  01-00-00  34 ST-HERALD SQ  BDFMNQRW      BMT
#
#                         DESC   ENTRIES     EXITS day_of_week  ENTRIES_diff  \
# DATE_TIME
# 2019-09-14 00:00:00  REGULAR  27614743  11470343    Saturday    338.405204
# 2019-09-14 04:00:00  REGULAR  27615069  11470409    Saturday    326.000000
# 2019-09-14 08:00:00  REGULAR  27615185  11470511    Saturday    116.000000
# 2019-09-14 12:00:00  REGULAR  27615767  11470904    Saturday    582.000000
# 2019-09-14 16:00:00  REGULAR  27616938  11471596    Saturday   1171.000000
#
#                      EXITS_diff  TRAFFIC_FLOW
# DATE_TIME
# 2019-09-14 00:00:00  327.412528    665.817732
# 2019-09-14 04:00:00   66.000000    392.000000
# 2019-09-14 08:00:00  102.000000    218.000000
# 2019-09-14 12:00:00  393.000000    975.000000
# 2019-09-14 16:00:00  692.000000   1863.000000

# %%
#top_entry_stations.loc['2019-09-14']['STATION'].min()

# %% [markdown]
# # Resample a specific station (can do with group if we want) to do timeseries analysis
# ## Here resampling daily ('D') and getting mean by DAY, can chain with others such as sum, testing with one station...might need to multi level index station / datetime to do more?

# %%
daily_mean_34st = top_entry_stations[top_entry_stations['STATION'] == '34 ST-HERALD SQ'].resample('4H').mean()

# %% [markdown]
# Can add sum/max etc on this in addition to mean

# %%
daily_mean_34st # ONLY 34 STREET TEST
# Out:
#                           ENTRIES         EXITS  ENTRIES_diff  EXITS_diff  \
# DATE_TIME
# 2019-09-14 00:00:00  8.558734e+07  1.070275e+08    338.405204  327.412528
# 2019-09-14 04:00:00  8.558742e+07  1.070276e+08     94.496489   39.888889
# 2019-09-14 08:00:00  8.558745e+07  1.070276e+08     51.348341   82.333333
# 2019-09-14 12:00:00  8.558761e+07  1.070279e+08    172.311304  293.277778
# 2019-09-14 16:00:00  8.558794e+07  1.070283e+08    359.829822  387.814815
# 2019-09-14 20:00:00  8.558834e+07  1.070287e+08    439.607600  412.351852
# 2019-09-15 00:00:00  8.558860e+07  1.070289e+08    298.940933  211.333333
# 2019-09-15 04:00:00  8.558867e+07  1.070290e+08     81.829822   41.518519
# 2019-09-15 08:00:00  8.558870e+07  1.070290e+08     40.959452   56.981481
# 2019-09-15 12:00:00  8.558882e+07  1.070293e+08    139.200193  264.796296
# 2019-09-15 16:00:00  8.558910e+07  1.070297e+08    317.403896  348.351852
# 2019-09-15 20:00:00  8.558947e+07  1.070300e+08    394.552045  331.111111
# 2019-09-16 00:00:00  8.558968e+07  1.070301e+08    242.477971  127.759259
# 2019-09-16 04:00:00  8.558971e+07  1.070301e+08     43.552045   17.240741
# 2019-09-16 08:00:00  8.558984e+07  1.070303e+08    143.737230  201.370370
# 2019-09-16 12:00:00  8.559022e+07  1.070311e+08    416.903896  736.944444
# 2019-09-16 16:00:00  8.559060e+07  1.070315e+08    404.626119  405.555556
# 2019-09-16 20:00:00  8.559147e+07  1.070321e+08    923.626119  629.259259
# 2019-09-17 00:00:00  8.559174e+07  1.070322e+08    293.292785  132.981481
# 2019-09-17 04:00:00  8.865960e+07  1.133229e+08     67.962875   42.480000
# 2019-09-17 08:00:00  8.559191e+07  1.070325e+08    115.292785  162.388889
# 2019-09-17 12:00:00  8.559229e+07  1.070332e+08    411.626119  768.148148
# 2019-09-17 16:00:00  8.559268e+07  1.070336e+08    418.515008  416.703704
# 2019-09-17 20:00:00  8.559360e+07  1.070343e+08    972.607600  617.574074
# 2019-09-18 00:00:00  8.559390e+07  1.070344e+08    324.440933  175.185185
# 2019-09-18 04:00:00  8.559394e+07  1.070345e+08     59.163156   23.611111
# 2019-09-18 08:00:00  8.559407e+07  1.070347e+08    148.533526  203.907407
# 2019-09-18 12:00:00  8.559447e+07  1.070354e+08    423.200193  763.851852
# 2019-09-18 16:00:00  8.559487e+07  1.070359e+08    426.237230  429.722222
# 2019-09-18 20:00:00  8.559580e+07  1.070365e+08    988.107600  660.000000
# 2019-09-19 00:00:00  8.559613e+07  1.070367e+08    353.477971  183.703704
# 2019-09-19 04:00:00  8.559617e+07  1.070367e+08     59.440933   23.333333
# 2019-09-19 08:00:00  8.559630e+07  1.070369e+08    143.070563  209.240741
# 2019-09-19 12:00:00  8.559669e+07  1.070377e+08    420.237230  749.888889
# 2019-09-19 16:00:00  8.559709e+07  1.070381e+08    435.366859  434.388889
# 2019-09-19 20:00:00  8.559801e+07  1.070388e+08    975.329822  646.574074
# 2019-09-20 00:00:00  8.559833e+07  1.070390e+08    349.885378  206.833333
# 2019-09-20 04:00:00  8.559839e+07  1.070390e+08     68.996489   29.611111
# 2019-09-20 08:00:00  8.559850e+07  1.070392e+08    133.866859  202.592593
# 2019-09-20 12:00:00  8.559887e+07  1.070399e+08    400.033526  709.500000
# 2019-09-20 16:00:00  8.559933e+07  1.070404e+08    485.848341  479.277778
# 2019-09-20 20:00:00  8.560021e+07  1.070411e+08    939.848341  675.333333
#
#                      TRAFFIC_FLOW
# DATE_TIME
# 2019-09-14 00:00:00    665.817732
# 2019-09-14 04:00:00    134.385378
# 2019-09-14 08:00:00    133.681674
# 2019-09-14 12:00:00    465.589082
# 2019-09-14 16:00:00    747.644637
# 2019-09-14 20:00:00    851.959452
# 2019-09-15 00:00:00    510.274267
# 2019-09-15 04:00:00    123.348341
# 2019-09-15 08:00:00     97.940933
# 2019-09-15 12:00:00    403.996489
# 2019-09-15 16:00:00    665.755748
# 2019-09-15 20:00:00    725.663156
# 2019-09-16 00:00:00    370.237230
# 2019-09-16 04:00:00     60.792785
# 2019-09-16 08:00:00    345.107600
# 2019-09-16 12:00:00   1153.848341
# 2019-09-16 16:00:00    810.181674
# 2019-09-16 20:00:00   1552.885378
# 2019-09-17 00:00:00    426.274267
# 2019-09-17 04:00:00    110.442875
# 2019-09-17 08:00:00    277.681674
# 2019-09-17 12:00:00   1179.774267
# 2019-09-17 16:00:00    835.218711
# 2019-09-17 20:00:00   1590.181674
# 2019-09-18 00:00:00    499.626119
# 2019-09-18 04:00:00     82.774267
# 2019-09-18 08:00:00    352.440933
# 2019-09-18 12:00:00   1187.052045
# 2019-09-18 16:00:00    855.959452
# 2019-09-18 20:00:00   1648.107600
# 2019-09-19 00:00:00    537.181674
# 2019-09-19 04:00:00     82.774267
# 2019-09-19 08:00:00    352.311304
# 2019-09-19 12:00:00   1170.126119
# 2019-09-19 16:00:00    869.755748
# 2019-09-19 20:00:00   1621.903896
# 2019-09-20 00:00:00    556.718711
# 2019-09-20 04:00:00     98.607600
# 2019-09-20 08:00:00    336.459452
# 2019-09-20 12:00:00   1109.533526
# 2019-09-20 16:00:00    965.126119
# 2019-09-20 20:00:00   1615.181674

# %%
# daily_mean_34st_reindex = daily_mean_34st.set_index

# %%
daily_mean_top_stations = top_entry_stations.resample('D').mean()

# %%
daily_mean_top_stations['TRAFFIC_FLOW']
# Out:
# DATE_TIME
# 2019-09-14    409.872322
# 2019-09-15    297.226324
# 2019-09-16    614.214339
# 2019-09-17    639.127077
# 2019-09-18    670.229314
# 2019-09-19    659.773677
# 2019-09-20    649.593313
# Freq: D, Name: TRAFFIC_FLOW, dtype: float64

# %% [markdown]
# ### This one might need to be edited a little once we have more than a week. Can select a week at a time

# %%
fourH_mean_FLOW_top_stations = top_entry_stations['TRAFFIC_FLOW'].resample('2H').mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/envs/metis/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TRAFFIC_FLOW'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-156-3fc02529ab64> in <module>
# ----> 1 fourH_mean_FLOW_top_stations = top_entry_stations['TRAFFIC_FLOW'].resample('2H').mean()
#
# /anaconda3/envs/metis/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# /anaconda3/envs/metis/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TRAFFIC_FLOW'

# %%
fourH_mean_FLOW_top_stations
# Out:
# DATE_TIME
# 2019-09-14 00:00:00     717.342432
# 2019-09-14 04:00:00      74.288317
# 2019-09-14 08:00:00     124.231515
# 2019-09-14 12:00:00     395.747718
# 2019-09-14 16:00:00     582.474720
# 2019-09-14 20:00:00     575.320418
# 2019-09-15 00:00:00     315.267005
# 2019-09-15 04:00:00      67.955973
# 2019-09-15 08:00:00      84.526458
# 2019-09-15 12:00:00     329.024974
# 2019-09-15 16:00:00     504.427994
# 2019-09-15 20:00:00     482.155538
# 2019-09-16 00:00:00     224.010137
# 2019-09-16 04:00:00      35.690203
# 2019-09-16 08:00:00     526.855835
# 2019-09-16 12:00:00     914.182244
# 2019-09-16 16:00:00     776.019039
# 2019-09-16 20:00:00    1222.979989
# 2019-09-17 00:00:00     329.799455
# 2019-09-17 04:00:00      55.292681
# 2019-09-17 08:00:00     545.172937
# 2019-09-17 12:00:00     882.967092
# 2019-09-17 16:00:00     798.766814
# 2019-09-17 20:00:00    1256.057615
# 2019-09-18 00:00:00     332.210352
# 2019-09-18 04:00:00      39.821706
# 2019-09-18 08:00:00     539.434595
# 2019-09-18 12:00:00     972.007170
# 2019-09-18 16:00:00     825.602464
# 2019-09-18 20:00:00    1289.467111
# 2019-09-19 00:00:00     350.126616
# 2019-09-19 04:00:00      42.142917
# 2019-09-19 08:00:00     517.812801
# 2019-09-19 12:00:00     947.541294
# 2019-09-19 16:00:00     831.449306
# 2019-09-19 20:00:00    1272.920882
# 2019-09-20 00:00:00     374.149603
# 2019-09-20 04:00:00      45.357859
# 2019-09-20 08:00:00     478.191146
# 2019-09-20 12:00:00     900.927051
# 2019-09-20 16:00:00     904.372155
# 2019-09-20 20:00:00    1194.562066
# Freq: 4H, Name: TRAFFIC_FLOW, dtype: float64

# %%
#fourH_mean_FLOW_top_stations.plot(kind='line')
fourH_mean_FLOW_top_stations.plot(kind='line', title='Traffic Flow Mean Every 4 Hours (for top 5 stations)', legend=True)

# %%
sns.boxplot(data=fourH_mean_FLOW_top_stations)

# %%
top_entry_stations_test = top_entry_stations.loc['2019-09-14', 'TRAFFIC_FLOW']

# %%
top_entry_stations_test.describe()
# Out:
# count     2034.000000
# mean       409.872322
# std        685.243450
# min          0.000000
# 25%         62.000000
# 50%        328.168937
# 75%        611.817865
# max      19064.435438
# Name: TRAFFIC_FLOW, dtype: float64

# %%
# Testing smoothing via rolling mean
# Apply a rolling mean with a 24 hour window: smoothed
### might not be working because date/time in one??
#smoothed = top_entry_stations['STATION']['2019-09-14'].rolling(window=1).mean()

# %%
#fourH_mean_FLOW_top_stations.rolling(window=1).mean().plot(legend=True, kind='line')

# %%
df.SCP
# Out:
# 0         02-00-00
# 1         02-00-00
# 2         02-00-00
# 3         02-00-00
# 4         02-00-00
#             ...
# 204923    00-05-01
# 204924    00-05-01
# 204925    00-05-01
# 204926    00-05-01
# 204927    00-05-01
# Name: SCP, Length: 204928, dtype: object

# %% [markdown]
# # Top 20 stations to then reduce based on external info (non-tourist areas etc.)

# %%
# groupby station (already made), 'traffic_flow' column sum, get last 20
# sum so we get cumulative sum after whole week (or dataset)
top_20_stations = gp_station['TRAFFIC_FLOW'].sum().sort_values().tail(20)

# %%
top_20_stations
# Out:
# STATION
# 59 ST              6.613582e+05
# CHAMBERS ST        7.034479e+05
# 72 ST              7.099087e+05
# FLUSHING-MAIN      7.268315e+05
# 96 ST              7.327256e+05
# 47-50 STS ROCK     7.596246e+05
# 14 ST              7.716227e+05
# PATH NEW WTC       7.995908e+05
# 59 ST COLUMBUS     8.950502e+05
# CANAL ST           9.425844e+05
# 125 ST             9.543053e+05
# 86 ST              1.129475e+06
# 42 ST-PORT AUTH    1.153200e+06
# FULTON ST          1.181248e+06
# TIMES SQ-42 ST     1.254592e+06
# 14 ST-UNION SQ     1.317749e+06
# 23 ST              1.336954e+06
# 34 ST-HERALD SQ    1.524057e+06
# GRD CNTRL-42 ST    1.788344e+06
# 34 ST-PENN STA     2.016361e+06
# Name: TRAFFIC_FLOW, dtype: float64

# %% [markdown]
# ### Picking top 5 from above based on census + gmaps api
# #### Once those are selected we can do further analyses
# - 34 ST-PENN STA-- delete
# - GRD CNTRL-42 ST-- delete
# - 34 ST-HERALD SQ = 10001
# - 23rd st zip = 10010
# - 14 ST-UNION SQ zip = 10003
# - TIMES SQ-42 ST--- delete
# - FULTON ST--- zip = 10038
# - 42 ST-PORT AUTH--- zip = 10036
# - 86 ST--- zip = 10028
# - 125 ST--- zip = 10027
# - CANAL ST--- zip = 10013
# - 59 ST COLUMBUS--- zip = 10023
