# %%
import pickle

# %%
with open('clean_df.pickle', 'rb') as read_file:
          pickle_df= pickle.load(read_file)

# %%
pickle_df
# Out:
#                  DATE_TIME     CA  UNIT       SCP        STATION LINENAME  \
# 0      2019-04-27 00:00:00   A002  R051  02-00-00          59 ST  NQR456W
# 1      2019-04-27 04:00:00   A002  R051  02-00-00          59 ST  NQR456W
# 2      2019-04-27 08:00:00   A002  R051  02-00-00          59 ST  NQR456W
# 3      2019-04-27 12:00:00   A002  R051  02-00-00          59 ST  NQR456W
# 4      2019-04-27 16:00:00   A002  R051  02-00-00          59 ST  NQR456W
# 5      2019-04-27 20:00:00   A002  R051  02-00-00          59 ST  NQR456W
# 6      2019-04-28 00:00:00   A002  R051  02-00-00          59 ST  NQR456W
# 7      2019-04-28 04:00:00   A002  R051  02-00-00          59 ST  NQR456W
# 8      2019-04-28 08:00:00   A002  R051  02-00-00          59 ST  NQR456W
# 9      2019-04-28 12:00:00   A002  R051  02-00-00          59 ST  NQR456W
# 10     2019-04-28 16:00:00   A002  R051  02-00-00          59 ST  NQR456W
# 11     2019-04-28 20:00:00   A002  R051  02-00-00          59 ST  NQR456W
# ...
