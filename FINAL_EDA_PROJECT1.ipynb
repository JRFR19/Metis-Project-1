# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import pickle
import seaborn as sns

# %matplotlib inline

# %%
im

# %%
def get_data(week_nums):
    url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"
    dfs = []
    col_names= ['CA','UNIT','SCP','STATION','LINENAME','DIVISION','DATE','TIME','DESC','ENTRIES','EXITS']
    for week_num in week_nums:
        file_url = url.format(week_num)
        dfs.append(pd.read_csv(file_url, sep=",", header=0, names = col_names, parse_dates=[['DATE', 'TIME']]))
    return pd.concat(dfs)
        
week_nums = [190504, 190511, 190518, 190525]
df = get_data(week_nums)

# %%
with open('test_carissa_df.pickle', 'rb') as read_file:
          df= pickle.load(read_file)

# %%
df.head()
# Out:
#             DATE_TIME    CA  UNIT       SCP STATION LINENAME DIVISION  \
# 0 2019-04-27 00:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 1 2019-04-27 04:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 2 2019-04-27 08:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 3 2019-04-27 12:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 4 2019-04-27 16:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
#
#       DESC  ENTRIES    EXITS
# 0  REGULAR  7035249  2384833
# 1  REGULAR  7035269  2384840
# 2  REGULAR  7035292  2384875
# 3  REGULAR  7035392  2384951
# 4  REGULAR  7035651  2385020

# %%
df['day_of_week'] = df['DATE_TIME'].dt.dayofweek

# %%
#df['HOUR'] = df['DATE_TIME'].map(int(time.split(':')[0]))
df['MONTH'] = df['DATE_TIME'].dt.month
# df['YEAR'] = df['DATE_TIME'].map(date_to_year)

# %%
df = df[df.DESC == 'REGULAR']

# %%
df.columns
# Out:
# Index(['DATE_TIME', 'CA', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION',
#        'DESC', 'ENTRIES', 'EXITS', 'day_of_week', 'MONTH'],
#       dtype='object')

# %%
df.head()
# Out:
#             DATE_TIME    CA  UNIT       SCP STATION LINENAME DIVISION  \
# 0 2019-04-27 00:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 1 2019-04-27 04:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 2 2019-04-27 08:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 3 2019-04-27 12:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 4 2019-04-27 16:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
#
#       DESC  ENTRIES    EXITS  day_of_week  MONTH
# 0  REGULAR  7035249  2384833            5      4
# 1  REGULAR  7035269  2384840            5      4
# 2  REGULAR  7035292  2384875            5      4
# 3  REGULAR  7035392  2384951            5      4
# 4  REGULAR  7035651  2385020            5      4

# %%
df["ENTRIES_DAY_BEFORE"] = (df.groupby(["CA", "UNIT", "SCP", "STATION"])["ENTRIES"].transform(lambda grp: grp.shift(1)))

# %%
df["EXITS_DAY_BEFORE"] = (df.groupby(["CA", "UNIT", "SCP", "STATION"])["EXITS"].transform(lambda grp: grp.shift(1)))

# %%
df.head()
# Out:
#             DATE_TIME    CA  UNIT       SCP STATION LINENAME DIVISION  \
# 0 2019-04-27 00:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 1 2019-04-27 04:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 2 2019-04-27 08:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 3 2019-04-27 12:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 4 2019-04-27 16:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
#
#       DESC  ENTRIES    EXITS  day_of_week  MONTH  ENTRIES_DAY_BEFORE  \
# 0  REGULAR  7035249  2384833            5      4                 NaN
# 1  REGULAR  7035269  2384840            5      4           7035249.0
# 2  REGULAR  7035292  2384875            5      4           7035269.0
# 3  REGULAR  7035392  2384951            5      4           7035292.0
# 4  REGULAR  7035651  2385020            5      4           7035392.0
#
#    EXITS_DAY_BEFORE
# 0               NaN
# 1         2384833.0
# 2         2384840.0
# 3         2384875.0
# 4         2384951.0

# %%
df.dropna(subset=["ENTRIES_DAY_BEFORE"], axis=0, inplace=True)

# %%
def get_daily_counts(row, max_counter):
    counter = row["ENTRIES"] - row["ENTRIES_DAY_BEFORE"] + row["EXITS"] - row["EXITS_DAY_BEFORE"]
    if counter < 0:
        counter = -counter
    if counter > max_counter:
        #print(row["ENTRIES"], row["PREV_ENTRIES"])
        return 0
    return counter

# %%
df["HOURLY_SUM"] = df.apply(get_daily_counts, axis=1, max_counter=1000000)

# %%
df.head()
# Out:
#             DATE_TIME    CA  UNIT       SCP STATION LINENAME DIVISION  \
# 1 2019-04-27 04:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 2 2019-04-27 08:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 3 2019-04-27 12:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 4 2019-04-27 16:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 5 2019-04-27 20:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
#
#       DESC  ENTRIES    EXITS  day_of_week  MONTH  ENTRIES_DAY_BEFORE  \
# 1  REGULAR  7035269  2384840            5      4           7035249.0
# 2  REGULAR  7035292  2384875            5      4           7035269.0
# 3  REGULAR  7035392  2384951            5      4           7035292.0
# 4  REGULAR  7035651  2385020            5      4           7035392.0
# 5  REGULAR  7035930  2385070            5      4           7035651.0
#
#    EXITS_DAY_BEFORE  HOURLY_SUM
# 1         2384833.0        27.0
# 2         2384840.0        58.0
# 3         2384875.0       176.0
# 4         2384951.0       328.0
# 5         2385020.0       329.0

# %%
df["HOURLY_SUM"] = df.groupby(['SCP','MONTH']).HOURLY_SUM.transform(lambda x: np.where((x<0)|(x>35000),x.mask((x<0)|(x>35000)).mean(),x))
#df["EXITS_DAY_BEFORE"] = df.groupby(['SCP','MONTH']).EXITS_DAY_BEFORE.transform(lambda x: np.where((x<0)|(x>20000),x.mask((x<0)|(x>20000)).mean(),x))

# %%
df.head()
# Out:
#             DATE_TIME    CA  UNIT       SCP STATION LINENAME DIVISION  \
# 1 2019-04-27 04:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 2 2019-04-27 08:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 3 2019-04-27 12:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 4 2019-04-27 16:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 5 2019-04-27 20:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
#
#       DESC  ENTRIES    EXITS  day_of_week  MONTH  ENTRIES_DAY_BEFORE  \
# 1  REGULAR  7035269  2384840            5      4           7035249.0
# 2  REGULAR  7035292  2384875            5      4           7035269.0
# 3  REGULAR  7035392  2384951            5      4           7035292.0
# 4  REGULAR  7035651  2385020            5      4           7035392.0
# 5  REGULAR  7035930  2385070            5      4           7035651.0
#
#    EXITS_DAY_BEFORE  HOURLY_SUM
# 1         2384833.0        27.0
# 2         2384840.0        58.0
# 3         2384875.0       176.0
# 4         2384951.0       328.0
# 5         2385020.0       329.0

# %%
top_15_stations_with_sum = df.groupby(['STATION'])['HOURLY_SUM'].sum().sort_values(ascending = False).head(15)
print(top_15_stations_with_sum)
# Out:
# STATION
# 34 ST-PENN STA     8.016840e+06
# GRD CNTRL-42 ST    6.853626e+06
# 34 ST-HERALD SQ    5.702104e+06
# 14 ST-UNION SQ     5.045479e+06
# TIMES SQ-42 ST     4.895134e+06
# 23 ST              4.808342e+06
# 42 ST-PORT AUTH    4.561923e+06
# FULTON ST          4.328372e+06
# 86 ST              4.125384e+06
# 125 ST             3.610646e+06
# 59 ST COLUMBUS     3.389135e+06
# CANAL ST           3.331187e+06
# 59 ST              3.022021e+06
# 14 ST              2.987765e+06
# 47-50 STS ROCK     2.930321e+06
# Name: HOURLY_SUM, dtype: float64

# %%
top_15_stations_with_sum.head(16)
# Out:
# STATION
# 34 ST-PENN STA     8.016840e+06
# GRD CNTRL-42 ST    6.853626e+06
# 34 ST-HERALD SQ    5.702104e+06
# 14 ST-UNION SQ     5.045479e+06
# TIMES SQ-42 ST     4.895134e+06
# 23 ST              4.808342e+06
# 42 ST-PORT AUTH    4.561923e+06
# FULTON ST          4.328372e+06
# 86 ST              4.125384e+06
# 125 ST             3.610646e+06
# 59 ST COLUMBUS     3.389135e+06
# CANAL ST           3.331187e+06
# 59 ST              3.022021e+06
# 14 ST              2.987765e+06
# 47-50 STS ROCK     2.930321e+06
# Name: HOURLY_SUM, dtype: float64

# %%
top_15 = list(top_15_stations_with_sum.index[:])

# %%
top_15
# Out:
# ['34 ST-PENN STA',
#  'GRD CNTRL-42 ST',
#  '34 ST-HERALD SQ',
#  '14 ST-UNION SQ',
#  'TIMES SQ-42 ST',
#  '23 ST',
#  '42 ST-PORT AUTH',
#  'FULTON ST',
#  '86 ST',
#  '125 ST',
#  '59 ST COLUMBUS',
#  'CANAL ST',
#  '59 ST',
#  '14 ST',
#  '47-50 STS ROCK']

# %%
df_top_15 = df[df['STATION'].isin(top_15)]

# %%
df_top_15['STATION'].nunique()
# Out:
# 15

# %%
df_top_15.head()
# Out:
#             DATE_TIME    CA  UNIT       SCP STATION LINENAME DIVISION  \
# 1 2019-04-27 04:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 2 2019-04-27 08:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 3 2019-04-27 12:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 4 2019-04-27 16:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 5 2019-04-27 20:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
#
#       DESC  ENTRIES    EXITS  day_of_week  MONTH  ENTRIES_DAY_BEFORE  \
# 1  REGULAR  7035269  2384840            5      4           7035249.0
# 2  REGULAR  7035292  2384875            5      4           7035269.0
# 3  REGULAR  7035392  2384951            5      4           7035292.0
# 4  REGULAR  7035651  2385020            5      4           7035392.0
# 5  REGULAR  7035930  2385070            5      4           7035651.0
#
#    EXITS_DAY_BEFORE  HOURLY_SUM
# 1         2384833.0        27.0
# 2         2384840.0        58.0
# 3         2384875.0       176.0
# 4         2384951.0       328.0
# 5         2385020.0       329.0

# %%
gb_station_top15 = df_top_15.groupby(['STATION'])['HOURLY_SUM'].sum().sort_values(ascending=False).head(15)

# %%
gb_station_top15.plot(kind='bar',title= "Top 15 Stations by Traffic in May 2019")

# %%
df_top_5 = df_top_15[df_top_15['STATION'].isin(['86 ST','59 ST COLUMBUS','23 ST','14 ST-UNION SQ','CANAL ST'])]

# %%
df_top_5.head()
# Out:
#                        CA  UNIT       SCP STATION LINENAME DIVISION     DESC  \
# DATE_TIME
# 2019-04-27 04:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-27 08:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-27 12:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-27 16:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-27 20:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
#
#                      ENTRIES  EXITS  day_of_week  MONTH  ENTRIES_DAY_BEFORE  \
# DATE_TIME
# 2019-04-27 04:00:00    53384  65846            5      4             53384.0
# 2019-04-27 08:00:00    53384  65899            5      4             53384.0
# 2019-04-27 12:00:00    53384  66056            5      4             53384.0
# 2019-04-27 16:00:00    53384  66332            5      4             53384.0
# 2019-04-27 20:00:00    53384  66535            5      4             53384.0
#
#                      EXITS_DAY_BEFORE  HOURLY_SUM
# DATE_TIME
# 2019-04-27 04:00:00           65840.0         6.0
# 2019-04-27 08:00:00           65846.0        53.0
# 2019-04-27 12:00:00           65899.0       157.0
# 2019-04-27 16:00:00           66056.0       276.0
# 2019-04-27 20:00:00           66332.0       203.0

# %%
gb_station_top5 = df_top_5.groupby(['STATION'])['HOURLY_SUM'].sum().sort_values(ascending=False).head(15)

# %%
gb_station_top5.plot(kind='bar',title= "MAY 2019 Best 5 Stations for Entries/Exits in Highest Median Income Area")

# %%
df_top_5.head(10)
# Out:
#                DATE_TIME    CA  UNIT       SCP STATION LINENAME DIVISION  \
# 3877 2019-04-27 04:00:00  A030  R083  01-00-00   23 ST      NRW      BMT
# 3878 2019-04-27 08:00:00  A030  R083  01-00-00   23 ST      NRW      BMT
# 3879 2019-04-27 12:00:00  A030  R083  01-00-00   23 ST      NRW      BMT
# 3880 2019-04-27 16:00:00  A030  R083  01-00-00   23 ST      NRW      BMT
# 3881 2019-04-27 20:00:00  A030  R083  01-00-00   23 ST      NRW      BMT
# 3882 2019-04-28 00:00:00  A030  R083  01-00-00   23 ST      NRW      BMT
# 3883 2019-04-28 04:00:00  A030  R083  01-00-00   23 ST      NRW      BMT
# 3884 2019-04-28 08:00:00  A030  R083  01-00-00   23 ST      NRW      BMT
# 3885 2019-04-28 12:00:00  A030  R083  01-00-00   23 ST      NRW      BMT
# 3886 2019-04-28 16:00:00  A030  R083  01-00-00   23 ST      NRW      BMT
#
#          DESC  ENTRIES  EXITS  day_of_week  MONTH  ENTRIES_DAY_BEFORE  \
# 3877  REGULAR    53384  65846            5      4             53384.0
# 3878  REGULAR    53384  65899            5      4             53384.0
# 3879  REGULAR    53384  66056            5      4             53384.0
# 3880  REGULAR    53384  66332            5      4             53384.0
# 3881  REGULAR    53384  66535            5      4             53384.0
# 3882  REGULAR    53384  66594            6      4             53384.0
# 3883  REGULAR    53384  66603            6      4             53384.0
# 3884  REGULAR    53384  66623            6      4             53384.0
# 3885  REGULAR    53384  66754            6      4             53384.0
# 3886  REGULAR    53384  66971            6      4             53384.0
#
#       EXITS_DAY_BEFORE  HOURLY_SUM
# 3877           65840.0         6.0
# 3878           65846.0        53.0
# 3879           65899.0       157.0
# 3880           66056.0       276.0
# 3881           66332.0       203.0
# 3882           66535.0        59.0
# 3883           66594.0         9.0
# 3884           66603.0        20.0
# 3885           66623.0       131.0
# 3886           66754.0       217.0

# %%
gb_station_top5_by_day_of_week = df_top_5.groupby(['day_of_week'])['HOURLY_SUM'].sum().head(15)

# %%
gb_station_top5_by_day_of_week.plot(kind='bar',title= "Top 5 Stations by Traffic in Highest Median Income Area")

# %%
df_top_5 = df_top_5.set_index('DATE_TIME')

# %%
df_top_5.head(50)
# Out:
#                        CA  UNIT       SCP STATION LINENAME DIVISION     DESC  \
# DATE_TIME
# 2019-04-27 04:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-27 08:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-27 12:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-27 16:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-27 20:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-28 00:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-28 04:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-28 08:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-28 12:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-28 16:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-28 20:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-29 00:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-29 04:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-29 08:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-29 12:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-29 16:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-29 20:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-30 00:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-30 04:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-30 08:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-30 12:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-30 16:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-30 20:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-05-01 00:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-05-01 04:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-05-01 08:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-05-01 12:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-05-01 16:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-05-01 20:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-05-02 00:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-05-02 04:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-05-02 08:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-05-02 12:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-05-02 16:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-05-02 20:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-05-03 00:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-05-03 04:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-05-03 08:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-05-03 12:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-05-03 16:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-05-03 20:00:00  A030  R083  01-00-00   23 ST      NRW      BMT  REGULAR
# 2019-04-27 04:00:00  A030  R083  01-00-01   23 ST      NRW      BMT  REGULAR
# 2019-04-27 08:00:00  A030  R083  01-00-01   23 ST      NRW      BMT  REGULAR
# 2019-04-27 12:00:00  A030  R083  01-00-01   23 ST      NRW      BMT  REGULAR
# 2019-04-27 16:00:00  A030  R083  01-00-01   23 ST      NRW      BMT  REGULAR
# 2019-04-27 20:00:00  A030  R083  01-00-01   23 ST      NRW      BMT  REGULAR
# 2019-04-28 00:00:00  A030  R083  01-00-01   23 ST      NRW      BMT  REGULAR
# 2019-04-28 04:00:00  A030  R083  01-00-01   23 ST      NRW      BMT  REGULAR
# 2019-04-28 08:00:00  A030  R083  01-00-01   23 ST      NRW      BMT  REGULAR
# 2019-04-28 12:00:00  A030  R083  01-00-01   23 ST      NRW      BMT  REGULAR
#
#                      ENTRIES    EXITS  day_of_week  MONTH  ENTRIES_DAY_BEFORE  \
# DATE_TIME
# 2019-04-27 04:00:00    53384    65846            5      4             53384.0
# 2019-04-27 08:00:00    53384    65899            5      4             53384.0
# 2019-04-27 12:00:00    53384    66056            5      4             53384.0
# 2019-04-27 16:00:00    53384    66332            5      4             53384.0
# 2019-04-27 20:00:00    53384    66535            5      4             53384.0
# 2019-04-28 00:00:00    53384    66594            6      4             53384.0
# 2019-04-28 04:00:00    53384    66603            6      4             53384.0
# 2019-04-28 08:00:00    53384    66623            6      4             53384.0
# 2019-04-28 12:00:00    53384    66754            6      4             53384.0
# 2019-04-28 16:00:00    53384    66971            6      4             53384.0
# 2019-04-28 20:00:00    53384    67138            6      4             53384.0
# 2019-04-29 00:00:00    53384    67190            0      4             53384.0
# 2019-04-29 04:00:00    53384    67197            0      4             53384.0
# 2019-04-29 08:00:00    53384    67341            0      4             53384.0
# 2019-04-29 12:00:00    53384    68019            0      4             53384.0
# 2019-04-29 16:00:00    53384    68323            0      4             53384.0
# 2019-04-29 20:00:00    53384    68683            0      4             53384.0
# 2019-04-30 00:00:00    53384    68738            1      4             53384.0
# 2019-04-30 04:00:00    53384    68743            1      4             53384.0
# 2019-04-30 08:00:00    53384    68874            1      4             53384.0
# 2019-04-30 12:00:00    53384    69604            1      4             53384.0
# 2019-04-30 16:00:00    53384    69965            1      4             53384.0
# 2019-04-30 20:00:00    53384    70363            1      4             53384.0
# 2019-05-01 00:00:00    53384    70448            2      5             53384.0
# 2019-05-01 04:00:00    53384    70460            2      5             53384.0
# 2019-05-01 08:00:00    53384    70595            2      5             53384.0
# 2019-05-01 12:00:00    53384    71288            2      5             53384.0
# 2019-05-01 16:00:00    53384    71645            2      5             53384.0
# 2019-05-01 20:00:00    53384    72040            2      5             53384.0
# 2019-05-02 00:00:00    53384    72120            3      5             53384.0
# 2019-05-02 04:00:00    53384    72127            3      5             53384.0
# 2019-05-02 08:00:00    53384    72271            3      5             53384.0
# 2019-05-02 12:00:00    53384    72965            3      5             53384.0
# 2019-05-02 16:00:00    53384    73310            3      5             53384.0
# 2019-05-02 20:00:00    53384    73720            3      5             53384.0
# 2019-05-03 00:00:00    53384    73847            4      5             53384.0
# 2019-05-03 04:00:00    53384    73853            4      5             53384.0
# 2019-05-03 08:00:00    53384    74011            4      5             53384.0
# 2019-05-03 12:00:00    53384    74617            4      5             53384.0
# 2019-05-03 16:00:00    53384    74970            4      5             53384.0
# 2019-05-03 20:00:00    53384    75360            4      5             53384.0
# 2019-04-27 04:00:00  6816531  2510839            5      4           6816477.0
# 2019-04-27 08:00:00  6816552  2510859            5      4           6816531.0
# 2019-04-27 12:00:00  6816723  2510946            5      4           6816552.0
# 2019-04-27 16:00:00  6817321  2511078            5      4           6816723.0
# 2019-04-27 20:00:00  6817939  2511202            5      4           6817321.0
# 2019-04-28 00:00:00  6818206  2511242            6      4           6817939.0
# 2019-04-28 04:00:00  6818288  2511251            6      4           6818206.0
# 2019-04-28 08:00:00  6818305  2511263            6      4           6818288.0
# 2019-04-28 12:00:00  6818420  2511295            6      4           6818305.0
#
#                      EXITS_DAY_BEFORE  HOURLY_SUM
# DATE_TIME
# 2019-04-27 04:00:00           65840.0         6.0
# 2019-04-27 08:00:00           65846.0        53.0
# 2019-04-27 12:00:00           65899.0       157.0
# 2019-04-27 16:00:00           66056.0       276.0
# 2019-04-27 20:00:00           66332.0       203.0
# 2019-04-28 00:00:00           66535.0        59.0
# 2019-04-28 04:00:00           66594.0         9.0
# 2019-04-28 08:00:00           66603.0        20.0
# 2019-04-28 12:00:00           66623.0       131.0
# 2019-04-28 16:00:00           66754.0       217.0
# 2019-04-28 20:00:00           66971.0       167.0
# 2019-04-29 00:00:00           67138.0        52.0
# 2019-04-29 04:00:00           67190.0         7.0
# 2019-04-29 08:00:00           67197.0       144.0
# 2019-04-29 12:00:00           67341.0       678.0
# 2019-04-29 16:00:00           68019.0       304.0
# 2019-04-29 20:00:00           68323.0       360.0
# 2019-04-30 00:00:00           68683.0        55.0
# 2019-04-30 04:00:00           68738.0         5.0
# 2019-04-30 08:00:00           68743.0       131.0
# 2019-04-30 12:00:00           68874.0       730.0
# 2019-04-30 16:00:00           69604.0       361.0
# 2019-04-30 20:00:00           69965.0       398.0
# 2019-05-01 00:00:00           70363.0        85.0
# 2019-05-01 04:00:00           70448.0        12.0
# 2019-05-01 08:00:00           70460.0       135.0
# 2019-05-01 12:00:00           70595.0       693.0
# 2019-05-01 16:00:00           71288.0       357.0
# 2019-05-01 20:00:00           71645.0       395.0
# 2019-05-02 00:00:00           72040.0        80.0
# 2019-05-02 04:00:00           72120.0         7.0
# 2019-05-02 08:00:00           72127.0       144.0
# 2019-05-02 12:00:00           72271.0       694.0
# 2019-05-02 16:00:00           72965.0       345.0
# 2019-05-02 20:00:00           73310.0       410.0
# 2019-05-03 00:00:00           73720.0       127.0
# 2019-05-03 04:00:00           73847.0         6.0
# 2019-05-03 08:00:00           73853.0       158.0
# 2019-05-03 12:00:00           74011.0       606.0
# 2019-05-03 16:00:00           74617.0       353.0
# 2019-05-03 20:00:00           74970.0       390.0
# 2019-04-27 04:00:00         2510830.0        63.0
# 2019-04-27 08:00:00         2510839.0        41.0
# 2019-04-27 12:00:00         2510859.0       258.0
# 2019-04-27 16:00:00         2510946.0       730.0
# 2019-04-27 20:00:00         2511078.0       742.0
# 2019-04-28 00:00:00         2511202.0       307.0
# 2019-04-28 04:00:00         2511242.0        91.0
# 2019-04-28 08:00:00         2511251.0        29.0
# 2019-04-28 12:00:00         2511263.0       147.0

# %%
fourH_hourly_sum_top_5 = df_top_5.groupby(['STATION'])['HOURLY_SUM'].resample('4H').sum()

# %%
fourH_hourly_sum_top_5.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-88890eee1ee1> in <module>
# ----> 1 fourH_hourly_sum_top_5.columns
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5061         if (name in self._internal_names_set or name in self._metadata or
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
fourH_hourly_sum_top_5.plot(kind='line', legend=True)

# %%
fourH_hourly_sum_top_5.plot(kind='line', legend=True).get_figure().savefig('output.png')

# %%
plt.figure(figsize=(16, 10))
plt.ylim(0, 1200)


plt.xlabel("Day of the week")
plt.ylabel("Entries + Exits")
plt.title("May 2019 - Best Canvassing Spots by Day in Highest NY Median Income Areas")
sns.despine(offset=50, trim=True)
sns.barplot(x=df_top_5.day_of_week, y=df_top_5.HOURLY_SUM, hue=df_top_5.STATION).get_figure().savefig('barplot_final.png');
